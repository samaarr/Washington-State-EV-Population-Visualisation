# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
df = pd.read_csv('Electric_Vehicle_Population_Data2.csv')

# %%
df.head(2)
# Out:
#    VIN (1-10)   County       City State  Postal Code  Model_Year      Make  \
# 0  2C4RC1N71H   Kitsap  Bremerton    WA      98311.0        2017  CHRYSLER
# 1  2C4RC1N7XL  Stevens   Colville    WA      99114.0        2020  CHRYSLER
#
#       Model                   Electric Vehicle Type  \
# 0  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
# 1  PACIFICA  Plug-in Hybrid Electric Vehicle (PHEV)
#
#   Clean Alternative Fuel Vehicle (CAFV) Eligibility  Electric_Range  \
# 0           Clean Alternative Fuel Vehicle Eligible            33.0
# 1           Clean Alternative Fuel Vehicle Eligible            32.0
#
#    Base MSRP  Legislative District  DOL Vehicle ID  \
# 0      39995                  23.0       349437882
# 1      39995                   7.0       154690532
#
#                   Vehicle Location        Electric Utility  2020 Census Tract  \
# 0  POINT (-122.6466274 47.6341188)  PUGET SOUND ENERGY INC       5.303509e+10
# ...

# %%
null_values = pd.DataFrame(df.isnull().sum())
null_values.plot(kind = 'bar' , title = 'Null values in the dataset')
plt.show()

# %%
df.dropna(inplace  = True)

# %%
df['Make'].nunique()
# Out:
# 38

# %%
df['City'].nunique()
# Out:
# 696

# %%
df['Model'].nunique()
# Out:
# 130

# %%
df['County'].nunique()
# Out:
# 184

# %%
df['Electric Vehicle Type'].value_counts() / 159467 * 100
# Out:
# Electric Vehicle Type
# Battery Electric Vehicle (BEV)            77.854979
# Plug-in Hybrid Electric Vehicle (PHEV)    22.145021
# Name: count, dtype: float64

# %%
df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts() / 159467* 100
# Out:
# Clean Alternative Fuel Vehicle (CAFV) Eligibility
# Eligibility unknown as battery range has not been researched    48.408135
# Clean Alternative Fuel Vehicle Eligible                         40.023328
# Not eligible due to low battery range                           11.568538
# Name: count, dtype: float64

# %%
cols = df[['Electric Vehicle Type' , 'Clean Alternative Fuel Vehicle (CAFV) Eligibility']]

# %%
type(cols)
# Out:
# pandas.core.frame.DataFrame

# %%
plt.figure(figsize=(11, 6))

# Subplot 1: Pie chart for CAFV eligibility
plt.subplot(121)
plt.pie(df['Clean Alternative Fuel Vehicle (CAFV) Eligibility'].value_counts(), autopct='%1.1f%%')
plt.title('Proportion of CAFV eligibility across the dataset')


# Subplot 2: Bar chart for Electric Vehicle Type
plt.subplot(122)
df['Electric Vehicle Type'].value_counts().plot(kind='bar')
plt.title('Proportion of PHEV and BEV vehicles in the dataset')

plt.show()
